# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from datetime import datetime as dt

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('Resources/hawaii_measurements.csv')
df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
# Convert the date column format from string to datetime
df.date = pd.to_datetime(df.date, infer_datetime_format= True)
df
# Out:
#            station       date  prcp  tobs
# 0      USC00519397 2010-01-01  0.08    65
# 1      USC00519397 2010-01-02  0.00    63
# 2      USC00519397 2010-01-03  0.00    74
# 3      USC00519397 2010-01-04  0.00    76
# 4      USC00519397 2010-01-06   NaN    73
# ...            ...        ...   ...   ...
# 19545  USC00516128 2017-08-19  0.09    71
# 19546  USC00516128 2017-08-20   NaN    78
# 19547  USC00516128 2017-08-21  0.56    76
# 19548  USC00516128 2017-08-22  0.50    76
# 19549  USC00516128 2017-08-23  0.45    76
#
# [19550 rows x 4 columns]

# %%
# Set the date column as the DataFrame index
df = df.set_index(df['date'])
df
# Out:
#                 station       date  prcp  tobs
# date
# 2010-01-01  USC00519397 2010-01-01  0.08    65
# 2010-01-02  USC00519397 2010-01-02  0.00    63
# 2010-01-03  USC00519397 2010-01-03  0.00    74
# 2010-01-04  USC00519397 2010-01-04  0.00    76
# 2010-01-06  USC00519397 2010-01-06   NaN    73
# ...                 ...        ...   ...   ...
# 2017-08-19  USC00516128 2017-08-19  0.09    71
# 2017-08-20  USC00516128 2017-08-20   NaN    78
# 2017-08-21  USC00516128 2017-08-21  0.56    76
# 2017-08-22  USC00516128 2017-08-22  0.50    76
# 2017-08-23  USC00516128 2017-08-23  0.45    76
#
# [19550 rows x 4 columns]

# %%
# Drop the date column
df = df.drop(columns='date')
df.head()
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-02  USC00519397  0.00    63
# 2010-01-03  USC00519397  0.00    74
# 2010-01-04  USC00519397  0.00    76
# 2010-01-06  USC00519397   NaN    73

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy import stats

# %%
# Filter data for desired months
jun_dec = df.loc[(df.index.month==12) | (df.index.month==6) ]
#df.loc[datetime.date(year=2014,month=1,day=1):datetime.date(year=2014,month=2,day=1)]
jun_dec
# Out:
#                 station  prcp  tobs
# date
# 2010-06-01  USC00519397  0.00    78
# 2010-06-02  USC00519397  0.01    76
# 2010-06-03  USC00519397  0.00    78
# 2010-06-04  USC00519397  0.00    76
# 2010-06-05  USC00519397  0.00    77
# ...                 ...   ...   ...
# 2017-06-26  USC00516128  0.02    79
# 2017-06-27  USC00516128  0.10    74
# 2017-06-28  USC00516128  0.02    74
# 2017-06-29  USC00516128  0.04    76
# 2017-06-30  USC00516128  0.20    75
#
# [3217 rows x 3 columns]

# %%
june = pd.DataFrame(df.loc[(df.index.month==6)]['tobs'])
dec = pd.DataFrame(df.loc[(df.index.month==12)]['tobs'])

# %%
# Identify the average temperature for June
j_avg = june.mean()
print(f"June Average: {j_avg['tobs']}")

# Identify the average temperature for December
d_avg = dec.mean()
print(f"December Average: {d_avg['tobs']}")
# Out:
# June Average: 74.94411764705882
# December Average: 71.04152933421226

# %%
# Identify the average temperature for June
j_avg = june.groupby(june.index.year).mean()
print(j_avg['tobs'].array[0:7])


d_avg = dec.groupby(dec.index.year).mean()
print(d_avg['tobs'].array)

# %%
# Create collections of temperature data
june = df.loc[(df.index.month==6)]['tobs']
dec = df.loc[(df.index.month==12)]['tobs']

# %%
# Run paired t-test
print(stats.ttest_rel(j_avg['tobs'].array[0:7], d_avg['tobs'].array))

# %% [markdown]
# ### Analysis

# %%
#The difference is significant.
